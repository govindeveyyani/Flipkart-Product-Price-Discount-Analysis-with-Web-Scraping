# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
Phone_name = []
Price = []
Discount = []
Ratings = []
Description = []

page_num = int(input("Enter number of pages :"))
for i in range(1, int(page_num)+1):
    url = "https://www.flipkart.com/search?q=mobile&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_2_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_3_na_na_na&as-pos=2&as-type=RECENT&suggestionId=mobile%7CMobiles&requestId=553a951a-5abd-4cf7-99e5-c08542285669&as-searchtext=mobile&p%5B%5D=facets.rating%255B%255D%3D3%25E2%2598%2585%2B%2526%2Babove&p%5B%5D=facets.discount_range_v1%255B%255D%3D10%2525%2Bor%2Bmore&page="+str(i)
    req = requests.get(url)
    content = BeautifulSoup(req.content, 'html.parser')
    name = content.find_all("div", class_ = "KzDlHZ")
    price = content.find_all("div", class_ = "Nx9bqj _4b5DiR")
    description = content.find_all("ul", class_ = "G4BRas")
    discount = content.find_all("div", class_ = "UkUFwK")
    rating = content.find_all("div", class_ = "XQDdHH")
    print("Phone in page " +str(i))
    print(len(name))

    for i in name:
        Phone_name.append(i.text)
    for i in price:
        Price.append(i.text)
    for i in description:
        Description.append(i.text)
    for i in discount:
        Discount.append(i.text)
    for i in rating:
        Ratings.append(i.text)
# Out:
# Enter number of pages : 11
# Phone in page 1
# 24
# Phone in page 2
# 24
# Phone in page 3
# 24
# Phone in page 4
# 24
# Phone in page 5
# 24
# Phone in page 6
# 24
# Phone in page 7
# 24
# Phone in page 8
# 24
# Phone in page 9
# 24
# Phone in page 10
# 24
# Phone in page 11
# 24

# %%
df = pd.DataFrame({"Name" : Phone_name,
                   "Price" : Price,
                   "Description" : Description,
                   "Discount" : Discount,
                   "Ratings" : Ratings
                  })

# %%
df
# Out:
#                                             Name    Price  \
# 0            realme P3 5G (Space Silver, 128 GB)  ₹16,999
# 1     SAMSUNG Galaxy F16 5G (Glam Green, 128 GB)  ₹14,499
# 2                POCO C61 (Ethereal Blue, 64 GB)   ₹5,699
# 3           POCO C61 (Diamond Dust Black, 64 GB)   ₹5,699
# 4      SAMSUNG Glaxy F06 5G (Lit Violet, 128 GB)   ₹9,199
# ..                                           ...      ...
# 259           Google Pixel 8a (Obsidian, 256 GB)  ₹44,999
# 260  SAMSUNG Galaxy F06 5G (Bahama Blue, 128 GB)  ₹10,699
# 261   SAMSUNG Galaxy F16 5G (Glam Green, 128 GB)  ₹11,499
# 262               vivo V50 5G (Rose Red, 256 GB)  ₹36,999
# 263            realme 14x 5G (Jewel Red, 128 GB)  ₹14,999
#
#                                            Description Discount Ratings
# 0    6 GB RAM | 128 GB ROM | Expandable Upto 2 TB16...  15% off     4.5
# 1    8 GB RAM | 128 GB ROM16.91 cm (6.657 inch) Ful...  23% off     4.3
# 2    4 GB RAM | 64 GB ROM | Expandable Upto 1 TB17....  36% off     4.2
# 3    4 GB RAM | 64 GB ROM | Expandable Upto 1 TB17....  36% off     4.2
# 4    4 GB RAM | 128 GB ROM | Expandable Upto 1500 G...  34% off     4.3
# ..                                                 ...      ...     ...
# 259  8 GB RAM | 256 GB ROM15.49 cm (6.1 inch) Full ...  25% off     4.3
# 260  6 GB RAM | 128 GB ROM | Expandable Upto 1500 G...  30% off     4.1
# 261  4 GB RAM | 128 GB ROM16.91 cm (6.657 inch) Ful...  28% off     4.2
# 262  8 GB RAM | 256 GB ROM17.2 cm (6.77 inch) Displ...  13% off     4.5
# 263  6 GB RAM | 128 GB ROM | Expandable Upto 2 TB16...  11% off     4.3
#
# [264 rows x 5 columns]

# %%
df.to_csv("C:/Users/vijay/OneDrive/Documents/Carrer prep plan/Flipkart Project/Flipkart_Scrapping.csv")
